# %%
import pandas as pd
import sys, os

sys.path.append(os.path.dirname(sys.path[0]))

# %%
reader = pd.read_csv(r'/home/gupessanha/Documentos/REPOS/SPSS/data/processed/neighbors.csv')

# %%
reader
# Out:
#           query_uid    query_name query_role aspect      metric  rank  \
# 0        2002078863    Scott King         AM      T  Euclidiana     1
# 1        2002078863    Scott King         AM      T  Euclidiana     2
# 2        2002078863    Scott King         AM      T  Euclidiana     3
# 3        2002078863    Scott King         AM      T  Euclidiana     4
# 4        2002078863    Scott King         AM      T  Euclidiana     5
# ...             ...           ...        ...    ...         ...   ...
# 9393955    37001809  Jordy Clasie        DEF     SP     Pearson     6
# 9393956    37001809  Jordy Clasie        DEF     SP     Pearson     7
# 9393957    37001809  Jordy Clasie        DEF     SP     Pearson     8
# 9393958    37001809  Jordy Clasie        DEF     SP     Pearson     9
# 9393959    37001809  Jordy Clasie        DEF     SP     Pearson    10
#
#          neighbor_uid      neighbor_name neighbor_role     score  score_kind
# ...

# %%
neymar = df.loc[df['query_name']== 'Igor Thiago']
